# %% [markdown]
# # 02 — Exploratory Data Analysis
# Generates the 10 figures from Report Section 3 via `src/visualizations.py`, using the *clean* (unencoded) dataset produced by notebook 01.

# %%
import sys, os
sys.path.append(os.path.abspath('../src'))
import pandas as pd
import seaborn as sns
sns.set_theme(style='whitegrid', palette='Set2')
import visualizations as viz

df = pd.read_csv('../data/airline_passenger_satisfaction_clean.csv')

# %%
viz.fig1_age_satisfaction(df)

# %%
viz.fig2_class_satisfaction(df)

# %%
viz.fig3_service_corr(df)

# %%
viz.fig4_delay_customertype(df)

# %%
viz.fig5_distance_delay(df)

# %%
viz.fig6_inflight_traveltype(df)

# %%
viz.fig7_customertype_stacked(df)

# %%
viz.fig8_pairplot_digital(df)

# %%
viz.fig9_facet_entertainment_comfort(df)

# %%
viz.fig10_friction_points(df)

# %% [markdown]
# All figures are written to `../figures/` and are the ones embedded in Section 3 of the report.
