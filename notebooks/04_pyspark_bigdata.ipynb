# %% [markdown]
# # 04 — PySpark Big Data Analysis
# Runs Report Section 5: distributed SQL aggregation and an MLlib Random Forest classifier via `src/spark_pipeline.py`.
#
# **Requires a local JDK 11 install with `JAVA_HOME` set** — see Report Section 5.4 for the environment-setup reflection and the memory-overhead issues encountered.

# %%
import sys, os
sys.path.append(os.path.abspath('../src'))
from spark_pipeline import build_spark_session, run

# %%
# Runs the full pipeline: SQL aggregation, VectorAssembler, MLlib RandomForestClassifier
run('../data/airline_passenger_satisfaction.csv')
