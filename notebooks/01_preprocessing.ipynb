# %% [markdown]
# # 01 — Preprocessing
# Runs Report Section 2 (imputation, outlier capping, encoding, scaling, feature engineering, class-balance check) via `src/preprocessing.py`.

# %%
import sys, os
sys.path.append(os.path.abspath('../src'))
from preprocessing import load_and_clean, encode_and_scale, check_class_balance

# %%
clean_df = load_and_clean('../data/airline_passenger_satisfaction.csv')
clean_df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel Class  Flight Distance  \
# 0    Male     Loyal Customer   54  Personal Travel   Eco            807.0
# 1  Female     Loyal Customer    7  Personal Travel   Eco            916.0
# 2    Male  disloyal Customer   34  Business travel   Eco            915.0
# 3  Female     Loyal Customer   34  Business travel   Eco           1695.0
# 4    Male     Loyal Customer   33  Business travel   Eco            639.0
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      1                                  4
# 1                      3                                  2
# 2                      2                                  3
# 3                      2                                  3
# 4                      2                                  3
#
#    Ease of Online booking  Gate location  ...  Leg room service  \
# 0                       2              5  ...                 3
# ...

# %%
check_class_balance(clean_df)
# Out:
# satisfaction
# neutral or dissatisfied    0.5485
# satisfied                  0.4515
# Name: proportion, dtype: float64

# %%
encoded_df = encode_and_scale(clean_df)
encoded_df.head()
# Out:
#    Age  Flight Distance  Inflight wifi service  \
# 0   54        -0.030647                      1
# 1    7         0.093076                      3
# 2   34         0.091941                      2
# 3   34         0.977299                      2
# 4   33        -0.221339                      2
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       2              5
# 1                                  2                       3              4
# 2                                  3                       2              3
# 3                                  3                       2              3
# 4                                  3                       1              2
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  ...  \
# 0               4                2             4                       4  ...
# ...

# %%
clean_df.to_csv('../data/airline_passenger_satisfaction_clean.csv', index=False)
encoded_df.to_csv('../data/airline_passenger_satisfaction_processed.csv', index=False)
print('Saved clean + processed datasets')
# Out:
# Saved clean + processed datasets
